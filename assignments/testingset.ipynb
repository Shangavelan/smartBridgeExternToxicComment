# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('DSC_4587.jpg',target_size=(120,120))
img
# Out:
# <PIL.Image.Image image mode=RGB size=120x120>

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img(r'birdDataset\test_data\blasti\DSC_6399.jpg',target_size=(120,120))
img
# Out:
# <PIL.Image.Image image mode=RGB size=120x120>
